# %%
import pandas as pd
import json
import ast
import warnings
from ast import literal_eval as le
import plotly.express as px

warnings.filterwarnings("ignore")
import requests
import pandas as pd
import urlexpander


def unshorten(url):
    if "http" not in url:
        url = "http://" + url

    try:
        short = urlexpander.expand(url)
    except:
        short = url

    if "_ERROR__" in short:
        return url
    else:
        return short


def one_url_df(df, column="n_urls", urls="urls"):
    df = df[df[column] == 1]
    df[urls] = df[urls].apply(lambda x: x[0])
    return df


def more_url_df(df, interaction, n="n_urls", urls="urls"):
    df = df[df[n] > 1]
    temp = []
    for i in df.iterrows():
        row = i[1].to_dict()
        for url in row[urls]:
            temp.append((url, row[interaction], row[n]))
    return (
        pd.DataFrame(temp)
        .drop_duplicates()
        .rename(columns={0: urls, 1: interaction, 2: n})
    )

def plot(df, x):
    fig = px.histogram(df, x)
    fig.show();
    
def fix(df):
    df["urls"] = df["urls"].apply(lambda x: le(x))
    df["n_urls"] = df["urls"].apply(lambda x: len(x))

def un(df):
    df["urls"] = df["urls"].apply(lambda x: unshorten(x))
    
def sort(df, column):
    df.sort_values(column, inplace=True, ascending=False)

# %% [markdown]
# # Top Shared

# %% [markdown]
# ## Top Interacted

# %%
import os

# %%
# top interacted all files paths
all_top_interacted = [
    "../Top_Interacted/Data/" + i
    for i in os.listdir("../Top_Interacted/Data/")
    if i.split(".")[-1] == "csv"
]
all_top_interacted
# Out:
# ['../Top_Interacted/Data/change_4_months.csv',
#  '../Top_Interacted/Data/change_dec.csv',
#  '../Top_Interacted/Data/instagram_4_months.csv',
#  '../Top_Interacted/Data/instagram_dec.csv',
#  '../Top_Interacted/Data/reddits_4_months.csv',
#  '../Top_Interacted/Data/reddits_dec.csv',
#  '../Top_Interacted/Data/twitter_4_months.csv',
#  '../Top_Interacted/Data/twitter_dec.csv',
#  '../Top_Interacted/Data/youtube_4_months.csv',
#  '../Top_Interacted/Data/youtube_dec.csv',
#  '../Top_Interacted/Data/_all_4_months.csv',
#  '../Top_Interacted/Data/_all_dec.csv']

# %%
all_top_interacted_4_months = [i for i in all_top_interacted if "4_months" in i]
all_top_interacted_4_months
# Out:
# ['../Top_Interacted/Data/change_4_months.csv',
#  '../Top_Interacted/Data/instagram_4_months.csv',
#  '../Top_Interacted/Data/reddits_4_months.csv',
#  '../Top_Interacted/Data/twitter_4_months.csv',
#  '../Top_Interacted/Data/youtube_4_months.csv',
#  '../Top_Interacted/Data/_all_4_months.csv']

# %%
all_top_interacted_dec = [i for i in all_top_interacted if "dec" in i]
all_top_interacted_dec
# Out:
# ['../Top_Interacted/Data/change_dec.csv',
#  '../Top_Interacted/Data/instagram_dec.csv',
#  '../Top_Interacted/Data/reddits_dec.csv',
#  '../Top_Interacted/Data/twitter_dec.csv',
#  '../Top_Interacted/Data/youtube_dec.csv',
#  '../Top_Interacted/Data/_all_dec.csv']

# %%
li_4 = []
for filename in all_top_interacted_4_months:
    df = pd.read_csv(filename, index_col=None)
    li_4.append(df)

df_top_interacted_4_months = pd.concat(li_4, ignore_index=True).drop(columns={"Unnamed: 0"})
df_top_interacted_4_months
# Out:
#                                              shared_url    id/url  \
# 0     https://www.change.org/p/all-world-leaders-des...  25752458
# 1     https://www.change.org/p/%D0%BC%D0%B8%D0%B4-%D...  13641580
# 2     https://www.change.org/p/%D0%BC%D0%B8%D0%B4-%D...  13641580
# 3     https://www.change.org/p/loma-vista-recordings...  13641580
# 4     https://www.change.org/p/loma-vista-recordings...  13641580
# ...                                                 ...       ...
# 1509  https://www.change.org/p/warner-brothers-keep-...  25699776
# 1510  https://www.change.org/p/warner-brothers-keep-...  25699776
# 1511                           http://www.eximp.com.co/  26128212
# 1512  https://www.change.org/p/walt-disney-back-john...  20186707
# 1513  https://www.facebook.com/Delihealth-1014197053...  26128212
#
#                                                    text  n_likes  total  \
# 0     sign this, the fate of the world depends on it...      2.0    2.0
# 1     Johnny hold on! Now the same script was writte...      1.0    1.0
# 2     Johnny hold on! Now the same script was writte...      1.0    1.0
# 3     Johnny hold on! Now the same script was writte...      1.0    1.0
# 4     Johnny hold on! Now the same script was writte...      1.0    1.0
# ...                                                 ...      ...    ...
# 1509  <a href="https://www.change.org/p/warner-broth...      0.0    0.0
# 1510  <a href="https://www.change.org/p/warner-broth...      0.0    0.0
# 1511  Granolas Delihealth\nEn Delihealth. Solicita t...      0.0    0.0
# 1512                            http://chng.it/VzrzLNcM      0.0    0.0
# 1513  Granolas Delihealth\nEn Delihealth. Solicita t...      0.0    0.0
#
#                                     url_id  media_id  n_replies  score  \
# 0      change_petition_comments_4_months_0       NaN        NaN    NaN
# 1      change_petition_comments_4_months_1       NaN        NaN    NaN
# 2      change_petition_comments_4_months_1       NaN        NaN    NaN
# 3      change_petition_comments_4_months_1       NaN        NaN    NaN
# 4      change_petition_comments_4_months_1       NaN        NaN    NaN
# ...                                    ...       ...        ...    ...
# 1509  change_petition_comments_4_months_10       NaN        NaN    NaN
# 1510  change_petition_comments_4_months_10       NaN        NaN    NaN
# 1511  change_petition_comments_4_months_11       NaN        NaN    NaN
# 1512  change_petition_comments_4_months_12       NaN        NaN    NaN
# 1513  change_petition_comments_4_months_11       NaN        NaN    NaN
#
#       user.id_str  retweet_count  favorite_count  n_views  n_dislikes  \
# 0             NaN            NaN             NaN      NaN         NaN
# 1             NaN            NaN             NaN      NaN         NaN
# 2             NaN            NaN             NaN      NaN         NaN
# 3             NaN            NaN             NaN      NaN         NaN
# 4             NaN            NaN             NaN      NaN         NaN
# ...           ...            ...             ...      ...         ...
# 1509          NaN            NaN             NaN      NaN         NaN
# 1510          NaN            NaN             NaN      NaN         NaN
# 1511          NaN            NaN             NaN      NaN         NaN
# 1512          NaN            NaN             NaN      NaN         NaN
# 1513          NaN            NaN             NaN      NaN         NaN
#
#       n_favorites  n_comments
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# ...           ...         ...
# 1509          NaN         NaN
# 1510          NaN         NaN
# 1511          NaN         NaN
# 1512          NaN         NaN
# 1513          NaN         NaN
#
# [1514 rows x 16 columns]

# %%
li_dec = []
for filename in all_top_interacted_dec:
    df = pd.read_csv(filename, index_col=None)
    li_dec.append(df)

df_top_interacted_dec = pd.concat(li_dec, ignore_index=True).drop(
    columns={"Unnamed: 0"}
)
df_top_interacted_dec
# Out:
#                                              shared_url    id/url  \
# 0     https://www.documentcloud.org/documents/583586...  25809054
# 1     https://www.documentcloud.org/documents/583586...  25809054
# 2     https://www.youtube.com/channel/UCjKNc-woAlnxt...  25809054
# 3     https://www.youtube.com/channel/UCjKNc-woAlnxt...  25809054
# 4     https://www.latimes.com/entertainment/gossip/l...  25809054
# ...                                                 ...       ...
# 1323  https://www.change.org/p/united-nations-remove...  14094292
# 1324  https://www.change.org/p/united-nations-remove...  14094292
# 1325  https://www.change.org/p/united-nations-remove...  22874214
# 1326  https://www.change.org/p/united-nations-remove...  22874214
# 1327  https://www.change.org/p/the-walt-disney-compa...  25829282
#
#                                                    text  n_likes  total  \
# 0     Amber Heard won and is innocent... UK Judge Ni...      9.0    9.0
# 1     Amber Heard won and is innocent... UK Judge Ni...      9.0    9.0
# 2     Amber Heard won and is innocent... UK Judge Ni...      9.0    9.0
# 3     Amber Heard won and is innocent... UK Judge Ni...      9.0    9.0
# 4     Amber Heard won and is innocent... UK Judge Ni...      9.0    9.0
# ...                                                 ...      ...    ...
# 1323  Another similar petition, please sign:\n\n<a h...      0.0    0.0
# 1324  Another similar petition, please sign:\n\n<a h...      0.0    0.0
# 1325  New petition against Amber Heard, please sign:...      0.0    0.0
# 1326  New petition against Amber Heard, please sign:...      0.0    0.0
# 1327  Johnny Depp deserves to get his career back. H...      0.0    0.0
#
#                                url_id  media_id  n_replies  score  \
# 0      change_petition_comments_dec_0       NaN        NaN    NaN
# 1      change_petition_comments_dec_0       NaN        NaN    NaN
# 2      change_petition_comments_dec_0       NaN        NaN    NaN
# 3      change_petition_comments_dec_0       NaN        NaN    NaN
# 4      change_petition_comments_dec_0       NaN        NaN    NaN
# ...                               ...       ...        ...    ...
# 1323  change_petition_comments_dec_13       NaN        NaN    NaN
# 1324  change_petition_comments_dec_13       NaN        NaN    NaN
# 1325  change_petition_comments_dec_14       NaN        NaN    NaN
# 1326  change_petition_comments_dec_14       NaN        NaN    NaN
# 1327  change_petition_comments_dec_15       NaN        NaN    NaN
#
#       user.id_str  retweet_count  favorite_count  n_views  n_dislikes  \
# 0             NaN            NaN             NaN      NaN         NaN
# 1             NaN            NaN             NaN      NaN         NaN
# 2             NaN            NaN             NaN      NaN         NaN
# 3             NaN            NaN             NaN      NaN         NaN
# 4             NaN            NaN             NaN      NaN         NaN
# ...           ...            ...             ...      ...         ...
# 1323          NaN            NaN             NaN      NaN         NaN
# 1324          NaN            NaN             NaN      NaN         NaN
# 1325          NaN            NaN             NaN      NaN         NaN
# 1326          NaN            NaN             NaN      NaN         NaN
# 1327          NaN            NaN             NaN      NaN         NaN
#
#       n_favorites  n_comments platform
# 0             NaN         NaN      NaN
# 1             NaN         NaN      NaN
# 2             NaN         NaN      NaN
# 3             NaN         NaN      NaN
# 4             NaN         NaN      NaN
# ...           ...         ...      ...
# 1323          NaN         NaN   change
# 1324          NaN         NaN   change
# 1325          NaN         NaN   change
# 1326          NaN         NaN   change
# 1327          NaN         NaN   change
#
# [1328 rows x 17 columns]

# %% [markdown]
# ## Shared URLs

# %%
shared_4_months = pd.read_csv("../URLs_Data/df_shared_4_months.csv")
shared_4_months.fillna("{1}", inplace=True)
shared_4_months["n_urls"] = shared_4_months["n_urls"].apply(lambda x: le(x))
shared_4_months.rename(columns={"shared_link": "shared_url"}, inplace=True)
shared_4_months.head(5)
# Out:
#                                           shared_url  n_shared  from_n_users  \
# 0  https://www.change.org/p/walt-disney-back-john...         6             1
# 1  https://www.change.org/p/me-johnny-depp-as-jac...         3             1
# 2  https://www.change.org/p/%D0%BC%D0%B8%D0%B4-%D...         2             1
# 3  https://www.change.org/p/loma-vista-recordings...         2             1
# 4  https://www.change.org/p/warner-brothers-keep-...         2             1
#
#            users n_urls platform              from
# 0  (1181480925,)    {1}   change  petition_comment
# 1  (1181480925,)    {1}   change  petition_comment
# 2   {1179297829}    {4}   change  petition_comment
# 3   {1179297829}    {4}   change  petition_comment
# 4   {1198070350}    {2}   change  petition_comment

# %%
shared_dec = pd.read_csv("../URLs_Data/df_shared_dec.csv")
shared_dec.rename(columns={"shared_link": "shared_url"}, inplace=True)
shared_dec.head(5)
# Out:
#                                           shared_url  n_shared  from_n_users  \
# 0  https://www.documentcloud.org/documents/583586...        16             4
# 1  https://www.latimes.com/entertainment/gossip/l...        16             4
# 2  https://www.truehollywoodtalk.com/amber-heards...        10             2
# 3  https://www.youtube.com/channel/UCjKNc-woAlnxt...         8             2
# 4  https://www.change.org/p/we-support-amber-hear...         6             1
#
#                                              users      n_urls platform  \
# 0  {948054032, 1129808400, 1136503772, 1081693988}  {8, 10, 4}   change
# 1  {948054032, 1129808400, 1136503772, 1081693988}  {8, 10, 4}   change
# 2                         {1136503772, 1081693988}  {8, 10, 2}   change
# 3                         {1136503772, 1081693988}     {8, 10}   change
# 4                                     {1081693988}        {10}   change
#
#                from
# 0  petition_comment
# 1  petition_comment
# 2  petition_comment
# 3  petition_comment
# 4  petition_comment

# %% [markdown]
# # 4

# %% [markdown]
# ### Top shared youtube across all platforms

# %%
top_shared_4_months_all_platforms = pd.merge(
    shared_4_months, df_top_interacted_4_months, how="inner"
)
top_shared_4_months_all_platforms = top_shared_4_months_all_platforms.sort_values(
    "total", ascending=False
).reset_index(drop=True)

# %%
top_shared_4_months_all_platforms
# Out:
#                                              shared_url  n_shared  \
# 0                         https://twitter.com/AmberryYt         1
# 1     https://www.youtube.com/watch?v=HIShWZkr0hs&li...         1
# 2            https://www.instagram.com/amberryphoeberry         1
# 3            https://www.instagram.com/amberryphoeberry         1
# 4     https://www.roblox.com/groups/3857126/Amberry-...         1
# ...                                                 ...       ...
# 1873  https://www.facebook.com/Delihealth-1014197053...         1
# 1874  https://www.facebook.com/Delihealth-1014197053...         1
# 1875  https://www.change.org/p/warner-brothers-keep-...         2
# 1876  https://www.change.org/p/warner-brothers-keep-...         2
# 1877  https://www.change.org/p/walt-disney-back-john...         6
#
#       from_n_users                         users n_urls platform  \
# 0                1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube
# 1                1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube
# 2                1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube
# 3                1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube
# 4                1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube
# ...            ...                           ...    ...      ...
# 1873             1                    {61693917}    {2}   change
# 1874             1                    {61693917}    {2}   change
# 1875             1                  {1198070350}    {2}   change
# 1876             1                  {1198070350}    {2}   change
# 1877             1                 (1181480925,)    {1}   change
#
#                   from                                       id/url  \
# 0              comment  https://www.youtube.com/watch?v=A1kOXoxgt18
# 1              comment  https://www.youtube.com/watch?v=A1kOXoxgt18
# 2              comment  https://www.youtube.com/watch?v=A1kOXoxgt18
# 3              comment  https://www.youtube.com/watch?v=A1kOXoxgt18
# 4              comment  https://www.youtube.com/watch?v=A1kOXoxgt18
# ...                ...                                          ...
# 1873  petition_comment                                     26128212
# 1874  petition_comment                                     26128212
# 1875  petition_comment                                     25699776
# 1876  petition_comment                                     25699776
# 1877  petition_comment                                     25717146
#
#                                                    text   n_likes  ...  \
# 0     the day olive was born... 1 million subscriber...  154907.0  ...
# 1     the day olive was born... 1 million subscriber...  154907.0  ...
# 2     the day olive was born... 1 million subscriber...  154907.0  ...
# 3     the day olive was born... 1 million subscriber...  154907.0  ...
# 4     the day olive was born... 1 million subscriber...  154907.0  ...
# ...                                                 ...       ...  ...
# 1873  Granolas Delihealth\nEn Delihealth. Solicita t...       0.0  ...
# 1874  Granolas Delihealth\nEn Delihealth. Solicita t...       0.0  ...
# 1875  <a href="https://www.change.org/p/warner-broth...       0.0  ...
# 1876  <a href="https://www.change.org/p/warner-broth...       0.0  ...
# 1877  Ahoj, k petici jsem se připojila a podepsala j...       0.0  ...
#
#       media_id n_replies  score  user.id_str  retweet_count  favorite_count  \
# 0          NaN       NaN    NaN          NaN            NaN             NaN
# 1          NaN       NaN    NaN          NaN            NaN             NaN
# 2          NaN       NaN    NaN          NaN            NaN             NaN
# 3          NaN       NaN    NaN          NaN            NaN             NaN
# 4          NaN       NaN    NaN          NaN            NaN             NaN
# ...        ...       ...    ...          ...            ...             ...
# 1873       NaN       NaN    NaN          NaN            NaN             NaN
# 1874       NaN       NaN    NaN          NaN            NaN             NaN
# 1875       NaN       NaN    NaN          NaN            NaN             NaN
# 1876       NaN       NaN    NaN          NaN            NaN             NaN
# 1877       NaN       NaN    NaN          NaN            NaN             NaN
#
#         n_views  n_dislikes  n_favorites  n_comments
# 0     7271086.0      4605.0          0.0     12352.0
# 1     7271086.0      4605.0          0.0     12352.0
# 2     7271086.0      4605.0          0.0     12352.0
# 3     7271086.0      4605.0          0.0     12352.0
# 4     7271086.0      4605.0          0.0     12352.0
# ...         ...         ...          ...         ...
# 1873        NaN         NaN          NaN         NaN
# 1874        NaN         NaN          NaN         NaN
# 1875        NaN         NaN          NaN         NaN
# 1876        NaN         NaN          NaN         NaN
# 1877        NaN         NaN          NaN         NaN
#
# [1878 rows x 22 columns]

# %%
saving = "Data/_"

# %%
top_shared_4_months_all_platforms.to_csv(saving + "top_shared_4_months_all_platforms.csv")

# %% [markdown]
# # DEC

# %% [markdown]
# ### Top shared change across all platforms

# %%
top_shared_dec_all_platforms = pd.merge(
    shared_dec, df_top_interacted_dec, how="inner"
)
top_shared_dec_all_platforms = top_shared_dec_all_platforms.sort_values(
    "total", ascending=False
).reset_index(drop=True)

# %%
top_shared_dec_all_platforms
# Out:
#                                             shared_url  n_shared  \
# 0                https://www.youtube.com/thebellatwins         1
# 1                              https://twitter.com/wwe         1
# 2                             http://wwe.yt/wwenetwork         1
# 3                                       http://wwe.yt/         1
# 4                 http://www.wwe.com/sonysportsnetwork         1
# ..                                                 ...       ...
# 471  https://www.change.org/p/united-nations-remove...         4
# 472  https://www.change.org/p/united-nations-remove...         4
# 473  https://www.change.org/p/united-nations-remove...         4
# 474  https://www.change.org/p/united-nations-remove...         4
# 475  https://www.change.org/p/united-nations-remove...         1
#
#      from_n_users                         users n_urls platform  \
# 0               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 1               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 2               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 3               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 4               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# ..            ...                           ...    ...      ...
# 471             1                  {1048865725}    {2}   change
# 472             1                  {1048865725}    {2}   change
# 473             1                  {1048865725}    {2}   change
# 474             1                  {1048865725}    {2}   change
# 475             1                 (1048865725,)    {1}   change
#
#                  from                                       id/url  \
# 0             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 1             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 2             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 3             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 4             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# ..                ...                                          ...
# 471  petition_comment                                     14094292
# 472  petition_comment                                     14094292
# 473  petition_comment                                     22874214
# 474  petition_comment                                     22874214
# 475  petition_comment                                     14094292
#
#                                                   text    n_likes  ...  \
# 0    full match - men's elimination chamber match: ...  1100425.0  ...
# 1    full match - men's elimination chamber match: ...  1100425.0  ...
# 2    full match - men's elimination chamber match: ...  1100425.0  ...
# 3    full match - men's elimination chamber match: ...  1100425.0  ...
# 4    full match - men's elimination chamber match: ...  1100425.0  ...
# ..                                                 ...        ...  ...
# 471  Another similar petition, please sign:\n\n<a h...        0.0  ...
# 472  Another similar petition, please sign:\n\n<a h...        0.0  ...
# 473  New petition against Amber Heard, please sign:...        0.0  ...
# 474  New petition against Amber Heard, please sign:...        0.0  ...
# 475  There's another new similar petition by DV sur...        0.0  ...
#
#      media_id n_replies  score  user.id_str  retweet_count  favorite_count  \
# 0         NaN       NaN    NaN          NaN            NaN             NaN
# 1         NaN       NaN    NaN          NaN            NaN             NaN
# 2         NaN       NaN    NaN          NaN            NaN             NaN
# 3         NaN       NaN    NaN          NaN            NaN             NaN
# 4         NaN       NaN    NaN          NaN            NaN             NaN
# ..        ...       ...    ...          ...            ...             ...
# 471       NaN       NaN    NaN          NaN            NaN             NaN
# 472       NaN       NaN    NaN          NaN            NaN             NaN
# 473       NaN       NaN    NaN          NaN            NaN             NaN
# 474       NaN       NaN    NaN          NaN            NaN             NaN
# 475       NaN       NaN    NaN          NaN            NaN             NaN
#
#         n_views  n_dislikes  n_favorites  n_comments
# 0    90110984.0     70870.0          0.0     20724.0
# 1    90110984.0     70870.0          0.0     20724.0
# 2    90110984.0     70870.0          0.0     20724.0
# 3    90110984.0     70870.0          0.0     20724.0
# 4    90110984.0     70870.0          0.0     20724.0
# ..          ...         ...          ...         ...
# 471         NaN         NaN          NaN         NaN
# 472         NaN         NaN          NaN         NaN
# 473         NaN         NaN          NaN         NaN
# 474         NaN         NaN          NaN         NaN
# 475         NaN         NaN          NaN         NaN
#
# [476 rows x 22 columns]

# %%
top_shared_dec_all_platforms.to_csv(saving + "top_shared_dec_all_platforms.csv")

# %%
top_shared_dec_all_platforms
# Out:
#                                             shared_url  n_shared  \
# 0                https://www.youtube.com/thebellatwins         1
# 1                              https://twitter.com/wwe         1
# 2                             http://wwe.yt/wwenetwork         1
# 3                                       http://wwe.yt/         1
# 4                 http://www.wwe.com/sonysportsnetwork         1
# ..                                                 ...       ...
# 471  https://www.change.org/p/united-nations-remove...         4
# 472  https://www.change.org/p/united-nations-remove...         4
# 473  https://www.change.org/p/united-nations-remove...         4
# 474  https://www.change.org/p/united-nations-remove...         4
# 475  https://www.change.org/p/united-nations-remove...         1
#
#      from_n_users                         users n_urls platform  \
# 0               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 1               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 2               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 3               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 4               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# ..            ...                           ...    ...      ...
# 471             1                  {1048865725}    {2}   change
# 472             1                  {1048865725}    {2}   change
# 473             1                  {1048865725}    {2}   change
# 474             1                  {1048865725}    {2}   change
# 475             1                 (1048865725,)    {1}   change
#
#                  from                                       id/url  \
# 0             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 1             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 2             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 3             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 4             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# ..                ...                                          ...
# 471  petition_comment                                     14094292
# 472  petition_comment                                     14094292
# 473  petition_comment                                     22874214
# 474  petition_comment                                     22874214
# 475  petition_comment                                     14094292
#
#                                                   text    n_likes  ...  \
# 0    full match - men's elimination chamber match: ...  1100425.0  ...
# 1    full match - men's elimination chamber match: ...  1100425.0  ...
# 2    full match - men's elimination chamber match: ...  1100425.0  ...
# 3    full match - men's elimination chamber match: ...  1100425.0  ...
# 4    full match - men's elimination chamber match: ...  1100425.0  ...
# ..                                                 ...        ...  ...
# 471  Another similar petition, please sign:\n\n<a h...        0.0  ...
# 472  Another similar petition, please sign:\n\n<a h...        0.0  ...
# 473  New petition against Amber Heard, please sign:...        0.0  ...
# 474  New petition against Amber Heard, please sign:...        0.0  ...
# 475  There's another new similar petition by DV sur...        0.0  ...
#
#      media_id n_replies  score  user.id_str  retweet_count  favorite_count  \
# 0         NaN       NaN    NaN          NaN            NaN             NaN
# 1         NaN       NaN    NaN          NaN            NaN             NaN
# 2         NaN       NaN    NaN          NaN            NaN             NaN
# 3         NaN       NaN    NaN          NaN            NaN             NaN
# 4         NaN       NaN    NaN          NaN            NaN             NaN
# ..        ...       ...    ...          ...            ...             ...
# 471       NaN       NaN    NaN          NaN            NaN             NaN
# 472       NaN       NaN    NaN          NaN            NaN             NaN
# 473       NaN       NaN    NaN          NaN            NaN             NaN
# 474       NaN       NaN    NaN          NaN            NaN             NaN
# 475       NaN       NaN    NaN          NaN            NaN             NaN
#
#         n_views  n_dislikes  n_favorites  n_comments
# 0    90110984.0     70870.0          0.0     20724.0
# 1    90110984.0     70870.0          0.0     20724.0
# 2    90110984.0     70870.0          0.0     20724.0
# 3    90110984.0     70870.0          0.0     20724.0
# 4    90110984.0     70870.0          0.0     20724.0
# ..          ...         ...          ...         ...
# 471         NaN         NaN          NaN         NaN
# 472         NaN         NaN          NaN         NaN
# 473         NaN         NaN          NaN         NaN
# 474         NaN         NaN          NaN         NaN
# 475         NaN         NaN          NaN         NaN
#
# [476 rows x 22 columns]

# %% [markdown]
# ## Shared across all platforms

# %%
top_shared_4_months_all_platforms[["n_shared", "total"]].corr()
# Out:
#           n_shared     total
# n_shared  1.000000 -0.053192
# total    -0.053192  1.000000

# %%
top_shared_dec_all_platforms[["n_shared", "total"]].corr()
# Out:
#           n_shared     total
# n_shared  1.000000 -0.165175
# total    -0.165175  1.000000

# %%
top_shared_dec_all_platforms = pd.read_csv(saving + "top_shared_dec_all_platforms.csv")

# %%
top_shared_dec_all_platforms
# Out:
#      Unnamed: 0                                         shared_url  n_shared  \
# 0             0              https://www.youtube.com/thebellatwins         1
# 1             1                            https://twitter.com/wwe         1
# 2             2                           http://wwe.yt/wwenetwork         1
# 3             3                                     http://wwe.yt/         1
# 4             4               http://www.wwe.com/sonysportsnetwork         1
# ..          ...                                                ...       ...
# 471         471  https://www.change.org/p/united-nations-remove...         4
# 472         472  https://www.change.org/p/united-nations-remove...         4
# 473         473  https://www.change.org/p/united-nations-remove...         4
# 474         474  https://www.change.org/p/united-nations-remove...         4
# 475         475  https://www.change.org/p/united-nations-remove...         1
#
#      from_n_users                         users n_urls platform  \
# 0               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 1               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 2               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 3               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 4               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# ..            ...                           ...    ...      ...
# 471             1                  {1048865725}    {2}   change
# 472             1                  {1048865725}    {2}   change
# 473             1                  {1048865725}    {2}   change
# 474             1                  {1048865725}    {2}   change
# 475             1                 (1048865725,)    {1}   change
#
#                  from                                       id/url  \
# 0             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 1             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 2             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 3             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 4             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# ..                ...                                          ...
# 471  petition_comment                                     14094292
# 472  petition_comment                                     14094292
# 473  petition_comment                                     22874214
# 474  petition_comment                                     22874214
# 475  petition_comment                                     14094292
#
#                                                   text  ...  media_id  \
# 0    full match - men's elimination chamber match: ...  ...       NaN
# 1    full match - men's elimination chamber match: ...  ...       NaN
# 2    full match - men's elimination chamber match: ...  ...       NaN
# 3    full match - men's elimination chamber match: ...  ...       NaN
# 4    full match - men's elimination chamber match: ...  ...       NaN
# ..                                                 ...  ...       ...
# 471  Another similar petition, please sign:\n\n<a h...  ...       NaN
# 472  Another similar petition, please sign:\n\n<a h...  ...       NaN
# 473  New petition against Amber Heard, please sign:...  ...       NaN
# 474  New petition against Amber Heard, please sign:...  ...       NaN
# 475  There's another new similar petition by DV sur...  ...       NaN
#
#      n_replies score  user.id_str  retweet_count  favorite_count     n_views  \
# 0          NaN   NaN          NaN            NaN             NaN  90110984.0
# 1          NaN   NaN          NaN            NaN             NaN  90110984.0
# 2          NaN   NaN          NaN            NaN             NaN  90110984.0
# 3          NaN   NaN          NaN            NaN             NaN  90110984.0
# 4          NaN   NaN          NaN            NaN             NaN  90110984.0
# ..         ...   ...          ...            ...             ...         ...
# 471        NaN   NaN          NaN            NaN             NaN         NaN
# 472        NaN   NaN          NaN            NaN             NaN         NaN
# 473        NaN   NaN          NaN            NaN             NaN         NaN
# 474        NaN   NaN          NaN            NaN             NaN         NaN
# 475        NaN   NaN          NaN            NaN             NaN         NaN
#
#      n_dislikes  n_favorites  n_comments
# 0       70870.0          0.0     20724.0
# 1       70870.0          0.0     20724.0
# 2       70870.0          0.0     20724.0
# 3       70870.0          0.0     20724.0
# 4       70870.0          0.0     20724.0
# ..          ...          ...         ...
# 471         NaN          NaN         NaN
# 472         NaN          NaN         NaN
# 473         NaN          NaN         NaN
# 474         NaN          NaN         NaN
# 475         NaN          NaN         NaN
#
# [476 rows x 23 columns]

# %%
with open("list_top_shared_urls.txt", "w") as f:
    f.write(str(list(top_shared_dec_all_platforms.shared_url.values)))

# %%
top_shared_dec_all_platforms
# Out:
#      Unnamed: 0                                         shared_url  n_shared  \
# 0             0              https://www.youtube.com/thebellatwins         1
# 1             1                            https://twitter.com/wwe         1
# 2             2                           http://wwe.yt/wwenetwork         1
# 3             3                                     http://wwe.yt/         1
# 4             4               http://www.wwe.com/sonysportsnetwork         1
# ..          ...                                                ...       ...
# 471         471  https://www.change.org/p/united-nations-remove...         4
# 472         472  https://www.change.org/p/united-nations-remove...         4
# 473         473  https://www.change.org/p/united-nations-remove...         4
# 474         474  https://www.change.org/p/united-nations-remove...         4
# 475         475  https://www.change.org/p/united-nations-remove...         1
#
#      from_n_users                         users n_urls platform  \
# 0               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 1               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 2               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 3               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 4               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# ..            ...                           ...    ...      ...
# 471             1                  {1048865725}    {2}   change
# 472             1                  {1048865725}    {2}   change
# 473             1                  {1048865725}    {2}   change
# 474             1                  {1048865725}    {2}   change
# 475             1                 (1048865725,)    {1}   change
#
#                  from                                       id/url  \
# 0             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 1             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 2             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 3             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 4             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# ..                ...                                          ...
# 471  petition_comment                                     14094292
# 472  petition_comment                                     14094292
# 473  petition_comment                                     22874214
# 474  petition_comment                                     22874214
# 475  petition_comment                                     14094292
#
#                                                   text  ...  media_id  \
# 0    full match - men's elimination chamber match: ...  ...       NaN
# 1    full match - men's elimination chamber match: ...  ...       NaN
# 2    full match - men's elimination chamber match: ...  ...       NaN
# 3    full match - men's elimination chamber match: ...  ...       NaN
# 4    full match - men's elimination chamber match: ...  ...       NaN
# ..                                                 ...  ...       ...
# 471  Another similar petition, please sign:\n\n<a h...  ...       NaN
# 472  Another similar petition, please sign:\n\n<a h...  ...       NaN
# 473  New petition against Amber Heard, please sign:...  ...       NaN
# 474  New petition against Amber Heard, please sign:...  ...       NaN
# 475  There's another new similar petition by DV sur...  ...       NaN
#
#      n_replies score  user.id_str  retweet_count  favorite_count     n_views  \
# 0          NaN   NaN          NaN            NaN             NaN  90110984.0
# 1          NaN   NaN          NaN            NaN             NaN  90110984.0
# 2          NaN   NaN          NaN            NaN             NaN  90110984.0
# 3          NaN   NaN          NaN            NaN             NaN  90110984.0
# 4          NaN   NaN          NaN            NaN             NaN  90110984.0
# ..         ...   ...          ...            ...             ...         ...
# 471        NaN   NaN          NaN            NaN             NaN         NaN
# 472        NaN   NaN          NaN            NaN             NaN         NaN
# 473        NaN   NaN          NaN            NaN             NaN         NaN
# 474        NaN   NaN          NaN            NaN             NaN         NaN
# 475        NaN   NaN          NaN            NaN             NaN         NaN
#
#      n_dislikes  n_favorites  n_comments
# 0       70870.0          0.0     20724.0
# 1       70870.0          0.0     20724.0
# 2       70870.0          0.0     20724.0
# 3       70870.0          0.0     20724.0
# 4       70870.0          0.0     20724.0
# ..          ...          ...         ...
# 471         NaN          NaN         NaN
# 472         NaN          NaN         NaN
# 473         NaN          NaN         NaN
# 474         NaN          NaN         NaN
# 475         NaN          NaN         NaN
#
# [476 rows x 23 columns]

# %%
top_shared_4_months_all_platforms
# Out:
#                                              shared_url  n_shared  \
# 0                         https://twitter.com/AmberryYt         1
# 1     https://www.youtube.com/watch?v=HIShWZkr0hs&li...         1
# 2            https://www.instagram.com/amberryphoeberry         1
# 3            https://www.instagram.com/amberryphoeberry         1
# 4     https://www.roblox.com/groups/3857126/Amberry-...         1
# ...                                                 ...       ...
# 1873  https://www.facebook.com/Delihealth-1014197053...         1
# 1874  https://www.facebook.com/Delihealth-1014197053...         1
# 1875  https://www.change.org/p/warner-brothers-keep-...         2
# 1876  https://www.change.org/p/warner-brothers-keep-...         2
# 1877  https://www.change.org/p/walt-disney-back-john...         6
#
#       from_n_users                         users n_urls platform  \
# 0                1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube
# 1                1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube
# 2                1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube
# 3                1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube
# 4                1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube
# ...            ...                           ...    ...      ...
# 1873             1                    {61693917}    {2}   change
# 1874             1                    {61693917}    {2}   change
# 1875             1                  {1198070350}    {2}   change
# 1876             1                  {1198070350}    {2}   change
# 1877             1                 (1181480925,)    {1}   change
#
#                   from                                       id/url  \
# 0              comment  https://www.youtube.com/watch?v=A1kOXoxgt18
# 1              comment  https://www.youtube.com/watch?v=A1kOXoxgt18
# 2              comment  https://www.youtube.com/watch?v=A1kOXoxgt18
# 3              comment  https://www.youtube.com/watch?v=A1kOXoxgt18
# 4              comment  https://www.youtube.com/watch?v=A1kOXoxgt18
# ...                ...                                          ...
# 1873  petition_comment                                     26128212
# 1874  petition_comment                                     26128212
# 1875  petition_comment                                     25699776
# 1876  petition_comment                                     25699776
# 1877  petition_comment                                     25717146
#
#                                                    text   n_likes  ...  \
# 0     the day olive was born... 1 million subscriber...  154907.0  ...
# 1     the day olive was born... 1 million subscriber...  154907.0  ...
# 2     the day olive was born... 1 million subscriber...  154907.0  ...
# 3     the day olive was born... 1 million subscriber...  154907.0  ...
# 4     the day olive was born... 1 million subscriber...  154907.0  ...
# ...                                                 ...       ...  ...
# 1873  Granolas Delihealth\nEn Delihealth. Solicita t...       0.0  ...
# 1874  Granolas Delihealth\nEn Delihealth. Solicita t...       0.0  ...
# 1875  <a href="https://www.change.org/p/warner-broth...       0.0  ...
# 1876  <a href="https://www.change.org/p/warner-broth...       0.0  ...
# 1877  Ahoj, k petici jsem se připojila a podepsala j...       0.0  ...
#
#       media_id n_replies  score  user.id_str  retweet_count  favorite_count  \
# 0          NaN       NaN    NaN          NaN            NaN             NaN
# 1          NaN       NaN    NaN          NaN            NaN             NaN
# 2          NaN       NaN    NaN          NaN            NaN             NaN
# 3          NaN       NaN    NaN          NaN            NaN             NaN
# 4          NaN       NaN    NaN          NaN            NaN             NaN
# ...        ...       ...    ...          ...            ...             ...
# 1873       NaN       NaN    NaN          NaN            NaN             NaN
# 1874       NaN       NaN    NaN          NaN            NaN             NaN
# 1875       NaN       NaN    NaN          NaN            NaN             NaN
# 1876       NaN       NaN    NaN          NaN            NaN             NaN
# 1877       NaN       NaN    NaN          NaN            NaN             NaN
#
#         n_views  n_dislikes  n_favorites  n_comments
# 0     7271086.0      4605.0          0.0     12352.0
# 1     7271086.0      4605.0          0.0     12352.0
# 2     7271086.0      4605.0          0.0     12352.0
# 3     7271086.0      4605.0          0.0     12352.0
# 4     7271086.0      4605.0          0.0     12352.0
# ...         ...         ...          ...         ...
# 1873        NaN         NaN          NaN         NaN
# 1874        NaN         NaN          NaN         NaN
# 1875        NaN         NaN          NaN         NaN
# 1876        NaN         NaN          NaN         NaN
# 1877        NaN         NaN          NaN         NaN
#
# [1878 rows x 22 columns]

# %%
top_shared = pd.concat([top_shared_dec_all_platforms, top_shared_4_months_all_platforms, ])

# %%
top_shared = top_shared[(top_shared.text.str.lower().str.contains(" amber h")) | (top_shared.text.str.lower().str.contains("johnny"))]

# %%
top_shared.to_csv("Top_Shared.csv", index=False)

# %%
import os
os.listdir("../URLs_Data/Youtube")
# Out:
# ['df_comments_4_months_urls.csv',
#  'df_comments_4_months_urls_with_users_count.csv',
#  'df_comments_dec_urls.csv',
#  'df_comments_dec_urls_with_users_count.csv',
#  'df_videos_4_months_urls_with_users_count.csv',
#  'df_videos_dec_urls.csv',
#  'df_videos_dec_urls_with_users_count.csv',
#  'df_videos_urls_4_months.csv']

# %%
os.listdir("../Top_Interacted/Data/")
# Out:
# ['change_4_months.csv',
#  'change_dec.csv',
#  'extras',
#  'instagram_4_months.csv',
#  'instagram_dec.csv',
#  'README.md',
#  'reddits_4_months.csv',
#  'reddits_dec.csv',
#  'Twitter',
#  'twitter_4_months.csv',
#  'twitter_dec.csv',
#  'Youtube',
#  'youtube_4_months.csv',
#  'youtube_dec.csv',
#  '_all_4_months.csv',
#  '_all_dec.csv']

# %%
all_youtube_top = pd.concat(
[pd.read_csv("../Top_Interacted/Data/youtube_4_months.csv"),
pd.read_csv("../Top_Interacted/Data/youtube_dec.csv")]
)

# %%
all_youtube_top.head(1)
# Out:
#    Unnamed: 0                    shared_url  \
# 0           0  https://youtu.be/Axcjv9YqYns
#
#                                         id/url  \
# 0  https://www.youtube.com/watch?v=UvsHWTGHmts
#
#                                                 text  n_likes  n_replies  \
# 0  Disney Officially Rehires Johnny Depp After Ca...   2174.0       82.0
#
#     total                       url_id  n_views  n_dislikes  n_favorites  \
# 0  2256.0  youtube_comments_4_months_0      NaN         NaN          NaN
#
#    n_comments
# 0         NaN

# %%
top_shared.head(1)
# Out:
#     Unnamed: 0                    shared_url  n_shared  from_n_users  \
# 28        28.0  https://youtu.be/hwkb80xzdus         1             1
#
#                             users n_urls platform     from  \
# 28  ('UCAIycRkUrsSP73CZIYFLCWw',)    {1}  youtube  comment
#
#                                          id/url  \
# 28  https://www.youtube.com/watch?v=h-wpBkiMKd0
#
#                                                  text  ...  media_id  \
# 28  caso de johnny depp y amber heard: amber es at...  ...       NaN
#
#     n_replies score  user.id_str  retweet_count  favorite_count    n_views  \
# 28        NaN   NaN          NaN            NaN             NaN  9402370.0
#
#     n_dislikes  n_favorites  n_comments
# 28      6188.0          0.0     18215.0
#
# [1 rows x 23 columns]

# %%
top_shared.columns
# Out:
# Index(['Unnamed: 0', 'shared_url', 'n_shared', 'from_n_users', 'users',
#        'n_urls', 'platform', 'from', 'id/url', 'text', 'n_likes', 'total',
#        'url_id', 'media_id', 'n_replies', 'score', 'user.id_str',
#        'retweet_count', 'favorite_count', 'n_views', 'n_dislikes',
#        'n_favorites', 'n_comments'],
#       dtype='object')

# %%
all_youtube_top = pd.merge(all_youtube_top,top_shared, on="id/url", how="left")

# %%
old = [i for i in all_youtube_top.columns if "_x" in i][1:]

# %%
new = [i[:-2] for i in all_youtube_top.columns if "_x" in i][1:]

# %%
dic = {}
for i in range(len(old)):
    dic[old[i]] = new[i]

# %%
all_youtube_top.rename(columns=dic, inplace=True)

# %%
all_youtube_top = all_youtube_top[new].sort_values("total", ascending=False)

# %%
top_shared.columns[1:]
# Out:
# Index(['shared_url', 'n_shared', 'from_n_users', 'users', 'n_urls', 'platform',
#        'from', 'id/url', 'text', 'n_likes', 'total', 'url_id', 'media_id',
#        'n_replies', 'score', 'user.id_str', 'retweet_count', 'favorite_count',
#        'n_views', 'n_dislikes', 'n_favorites', 'n_comments'],
#       dtype='object')

# %%
all_youtube_top.columns[1:]
# Out:
# Index(['text', 'n_likes', 'n_replies', 'total', 'url_id', 'n_views',
#        'n_dislikes', 'n_favorites', 'n_comments'],
#       dtype='object')

# %%
set(top_shared.columns[1:]) - set(all_youtube_top.columns[1:])
# Out:
# {'favorite_count',
#  'from',
#  'from_n_users',
#  'id/url',
#  'media_id',
#  'n_shared',
#  'n_urls',
#  'platform',
#  'retweet_count',
#  'score',
#  'shared_url',
#  'user.id_str',
#  'users'}

# %%
all_youtube_top["n_shared"] = 0

# %%
top_with_yt = pd.concat([top_shared, all_youtube_top]).drop(columns="Unnamed: 0").reset_index(drop=True).sort_values("total", ascending=False)

# %%
top_with_yt
# Out:
#                                              shared_url  n_shared  \
# 1099               http://www.wwe.com/sonysportsnetwork         0
# 1098                                http://shop.wwe.com         0
# 1088              https://www.youtube.com/wwetotaldivas         0
# 1089                    https://link.chtbl.com/7fp6uoqk         0
# 1090                  http://bit.ly/afterthebellpodcast         0
# ...                                                 ...       ...
# 234   https://www.change.org/p/united-nations-remove...         4
# 233   https://www.change.org/p/united-nations-remove...         4
# 232   https://www.change.org/p/the-walt-disney-compa...         1
# 231   https://www.change.org/p/dc-entertainment-remo...         1
# 1086  https://www.change.org/p/warner-brothers-keep-...         2
#
#       from_n_users          users n_urls platform              from    id/url  \
# 1099           NaN            NaN    NaN      NaN               NaN       NaN
# 1098           NaN            NaN    NaN      NaN               NaN       NaN
# 1088           NaN            NaN    NaN      NaN               NaN       NaN
# 1089           NaN            NaN    NaN      NaN               NaN       NaN
# 1090           NaN            NaN    NaN      NaN               NaN       NaN
# ...            ...            ...    ...      ...               ...       ...
# 234            1.0   {1048865725}    {2}   change  petition_comment  22874214
# 233            1.0   {1048865725}    {2}   change  petition_comment  22874214
# 232            1.0  (1167331579,)    {1}   change  petition_comment  25829282
# 231            1.0    (95107240,)    {1}   change  petition_comment  26152026
# 1086           1.0   {1198070350}    {2}   change  petition_comment  25699776
#
#                                                    text    n_likes  ...  \
# 1099  full match - men's elimination chamber match: ...  1100425.0  ...
# 1098  full match - men's elimination chamber match: ...  1100425.0  ...
# 1088  full match - men's elimination chamber match: ...  1100425.0  ...
# 1089  full match - men's elimination chamber match: ...  1100425.0  ...
# 1090  full match - men's elimination chamber match: ...  1100425.0  ...
# ...                                                 ...        ...  ...
# 234   New petition against Amber Heard, please sign:...        0.0  ...
# 233   New petition against Amber Heard, please sign:...        0.0  ...
# 232   Johnny Depp deserves to get his career back. H...        0.0  ...
# 231   KAITLYN HAESTIER-KAITLYN HAESTIER\nPlease note...        0.0  ...
# 1086  <a href="https://www.change.org/p/warner-broth...        0.0  ...
#
#       media_id n_replies  score  user.id_str  retweet_count  favorite_count  \
# 1099       NaN       NaN    NaN          NaN            NaN             NaN
# 1098       NaN       NaN    NaN          NaN            NaN             NaN
# 1088       NaN       NaN    NaN          NaN            NaN             NaN
# 1089       NaN       NaN    NaN          NaN            NaN             NaN
# 1090       NaN       NaN    NaN          NaN            NaN             NaN
# ...        ...       ...    ...          ...            ...             ...
# 234        NaN       NaN    NaN          NaN            NaN             NaN
# 233        NaN       NaN    NaN          NaN            NaN             NaN
# 232        NaN       NaN    NaN          NaN            NaN             NaN
# 231        NaN       NaN    NaN          NaN            NaN             NaN
# 1086       NaN       NaN    NaN          NaN            NaN             NaN
#
#          n_views  n_dislikes  n_favorites  n_comments
# 1099  90110984.0     70870.0          0.0     20724.0
# 1098  90110984.0     70870.0          0.0     20724.0
# 1088  90110984.0     70870.0          0.0     20724.0
# 1089  90110984.0     70870.0          0.0     20724.0
# 1090  90110984.0     70870.0          0.0     20724.0
# ...          ...         ...          ...         ...
# 234          NaN         NaN          NaN         NaN
# 233          NaN         NaN          NaN         NaN
# 232          NaN         NaN          NaN         NaN
# 231          NaN         NaN          NaN         NaN
# 1086         NaN         NaN          NaN         NaN
#
# [5454 rows x 22 columns]

# %%
top_with_yt.to_csv("top_shared_all_top_yt.csv", index=False)
